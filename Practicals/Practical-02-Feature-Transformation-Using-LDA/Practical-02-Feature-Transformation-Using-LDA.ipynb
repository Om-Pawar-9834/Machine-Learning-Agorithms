# %% [markdown]
# # We import
#
# | Library            | Purpose                  |
# | ------------------ | ------------------------ |
# | pandas             | Dataset                  |
# | numpy              | Numerical operations     |
# | load_digits        | High-dimensional dataset |
# | train_test_split   | Split train/test         |
# | StandardScaler     | Normalize data           |
# | PCA                | Dimensionality reduction |
# | LDA                | Dimensionality reduction |
# | LogisticRegression | Classification           |
# | accuracy_score     | Evaluate model           |
# | time               | Measure execution time   |

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import time

# %% [markdown]
# # Load Dataset
#
# Here we'll use the Digits Dataset.
#
# It has
#
# 1797 samples
# 64 features
# 10 classes

# %%
digits = load_digits()

X = digits.data
y = digits.target

print(X.shape)
print(y.shape)
# Out:
# (1797, 64)
# (1797,)

# %% [markdown]
# # Standardize Data

# %%
scaler = StandardScaler()    # It help to maintain data in perticular range

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Split Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,            # 80% training data and 20% testing data
    random_state=42
)

# %% [markdown]
# # PCA

# %%
start = time.time()
pca = PCA(n_components=20)

X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

pca_time = time.time() - start
print("PCA Time:", pca_time)
# Out:
# PCA Time: 0.023909568786621094

# %% [markdown]
#  # Train Model on PCA Data

# %%
model_pca = LogisticRegression(max_iter=1000)

model_pca.fit(X_train_pca, y_train)

pred_pca = model_pca.predict(X_test_pca)
acc_pca = accuracy_score(y_test, pred_pca)

print("PCA Accuracy:", acc_pca)
# Out:
# PCA Accuracy: 0.9388888888888889

# %% [markdown]
# # LDA
#
# Unlike PCA,
#
# LDA needs class labels.
#
# Maximum components
#
# Number of Classes − 1

# %%
start = time.time()

lda = LinearDiscriminantAnalysis(n_components=9)

X_train_lda = lda.fit_transform(X_train, y_train)
X_test_lda = lda.transform(X_test)

lda_time = time.time() - start
print("LDA Time:", lda_time)
# Out:
# LDA Time: 0.02892446517944336

# %% [markdown]
# # Train Model on LDA Data

# %%
model_lda = LogisticRegression(max_iter=1000)

model_lda.fit(X_train_lda, y_train)

pred_lda = model_lda.predict(X_test_lda)

acc_lda = accuracy_score(y_test, pred_lda)

print("LDA Accuracy:", acc_lda)
# Out:
# LDA Accuracy: 0.9472222222222222

# %% [markdown]
# # Compare Results

# %%
print("\nComparison")
print("-------------------------")
print("PCA Accuracy :", acc_pca)
print("LDA Accuracy :", acc_lda)

print()

print("PCA Time :", pca_time)
print("LDA Time :", lda_time)
# Out:
# Comparison
# -------------------------
# PCA Accuracy : 0.9388888888888889
# LDA Accuracy : 0.9472222222222222
#
# PCA Time : 0.023909568786621094
# LDA Time : 0.02892446517944336
